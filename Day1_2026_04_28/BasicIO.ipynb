# %% [markdown]
# I took these labs from An Introduction to Statistical Learning with Applications in Python (ISLP) Chapter 2.
# Copyright belong to ISLP authors!
# Checkout at https://www.statlearning.com for more information

# %%
print('fit a model with',11,'variables')
# Out:
# fit a model with 11 variables

# %% [markdown]
# Adding two integers in Python is pretty intuitive

# %%
3+5
# Out:
# 8

# %% [markdown]
# In python, textual data handled using strings. For instance, "hello" and 'hello' are strings. We can **concatenate** them using the addition + symbol.

# %%
demoText ='handsome guy!'
print("Hello "+ demoText)
# Out:
# Hello handsome guy!

# %% [markdown]
# A string is actually a type of _sequence_: this is a generic term for an ordered list. The three most important types of sequence are lists, tuples, and strings. I introduce lists now.
# The following command instructs Python to join together the number 3, 4, and 5, and to save them as a list named _x_
# When I type _x_, it gives us back the list.

# %%
x=[3, 4, 5]
x
# Out:
# [3, 4, 5]

# %% [markdown]
# Note that we use the brackets [] to construct this list.
#     I will often want to add two sets of numbers together. It is reasonable to try the following code, though it will not produce the desired results.

# %%
y=[1, 2, 3]
x+y
# Out:
# [3, 4, 5, 1, 2, 3]

# %% [markdown]
# The result may appear slightly counterintuitive: why did Python not add the entries of the lists element-by-element? In Python, lists hold arbitrary objects, and are added using **concatenation**. In fact, **concatenation** is the behavior we saw earlier when we enter "Hello " + demoText. This example reflects that Python is a general-purpose programming language.  Much of Python's data-specific comes from other packages, notably **numpy** and **pandas**.
